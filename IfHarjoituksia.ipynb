# %%
num1 = input("give number 1")
num2 = input("give number 2")

try:
    val1 = int(num1)
    val2 = int(num1)

    if val1 > val2:
        print("number 1 is higher")
    else:
        print("number 2 is higher or equal")

except ValueError:
    print("not an int")
# Out:
# not an int
