# %%
name1 = input("give name 1")
name2 = input("give name 2")
name3 = input("give name 3")


if name1 == name2:
    print("names 1 and 2 are the same")
elif name1 == name3:
    print("names 1 and 3 are the same")
# Out:
# number 2 is higher or equal
